# %% [markdown]
# # Categorizing Emotion Words

# %%
#Packages to help with analysis
import matplotlib.pyplot as plt
import nltk, re, tweepy 
import numpy as np
import pandas as pd
import pyreadstat
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
import gensim
from collections import Counter
import sklearn
from textblob import TextBlob
from sklearn.manifold import TSNE
from textblob import Word
from spellchecker import SpellChecker
# %matplotlib inline

# %% [markdown]
# ## Let's Take a Look at the Data from The COVID-19 Well-Being Dataset

# %%
pd.set_option('display.max_columns', None)

# %%
df, meta = pyreadstat.read_sav('Emotional Well-Being - CASEL COVID-19 Webinar_Anon.sav')

# %%
df.head()
# Out:
#             StartDate             EndDate  Progress  Duration__in_seconds_  \
# 0 2020-03-24 16:47:03 2020-03-24 16:52:06     100.0                  302.0
# 1 2020-03-24 16:48:25 2020-03-24 16:52:45     100.0                  259.0
# 2 2020-03-24 16:51:16 2020-03-24 16:52:49     100.0                   92.0
# 3 2020-03-24 16:47:38 2020-03-24 16:53:13     100.0                  334.0
# 4 2020-03-24 16:46:45 2020-03-24 16:53:26     100.0                  400.0
#
#    Finished        RecordedDate         ResponseId OpenEmotions_1  \
# 0       1.0 2020-03-24 16:52:06  R_Q64hfjjdCiGnM09        Anxious
# 1       1.0 2020-03-24 16:52:45  R_Anw03Hj4s7jxnfH        anxiety
# 2       1.0 2020-03-24 16:52:49  R_32UYohfSNVrkECi
# 3       1.0 2020-03-24 16:53:13  R_24PeWDZ57ldPxMy           Fear
# 4       1.0 2020-03-24 16:53:26  R_wMCGldjiVHje0o1          Panic
#
#   OpenEmotions_3 OpenEmotions_4  ClosedEmotions_1  ClosedEmotions_2  \
# 0            Sad        Fearful               6.0               6.0
# 1           fear           hope               5.0               6.0
# 2                                             NaN               NaN
# 3        Sadness          Anger               5.0               5.0
# 4         Terror     Depression               3.0               5.0
#
#    ClosedEmotions_3  ClosedEmotions_4  ClosedEmotions_5  ClosedEmotions_6  \
# 0               3.0               5.0               5.0               3.0
# 1               3.0               4.0               3.0               4.0
# 2               NaN               NaN               NaN               NaN
# 3               4.0               5.0               4.0               3.0
# 4               4.0               4.0               4.0               5.0
#
#        StressCauses_1              StressCauses_12         StressCauses_13  \
# 0         uncertainty                         News                 updates
# 1  worry about others             worry about self  loss of normal routine
# 2
# 3         Uncertainty                       Change                Finances
# 4  Fear for my health  Fear for my family’s health        Social isolation
#
#               JoyCauses_1       JoyCauses_12           JoyCauses_13  \
# 0                    kids               work                 family
# 1  connecting with others
# 2
# 3                  Family      Connectedness                  Quiet
# 4          My son’s smile  My son’s laughter  Old VMs from a friend
#
#   Strats_EffectiveSelf_1  Strats_EffectiveSelf_2 Strats_EffectiveSelf_3  \
# 0      stop soical media                 running             journaling
# 1                   yoga  connecting with others
# 2
# 3              Breathing              Meditation               Exercise
# 4                   Yoga                     EFT                 Nature
#
#   Strats_EffectiveOthe_1 Strats_EffectiveOthe_2 Strats_EffectiveOthe_3  ER_1  \
# 0                                                                        NaN
# 1         listen to them          provide facts      provide resources   3.0
# 2                                                                        NaN
# 3        Calm leadership             Meditation               Optimism   5.0
# 4           Outside time    Validating feelings                Hugging   5.0
#
#    ER_2         WellBeingSupport_16  \
# 0   NaN
# 1   4.0      Less cognitive demands
# 2   NaN
# 3   6.0                 Reassurance
# 4   5.0  Acceptance of all feelings
#
#                                  WellBeingSupport_17  \
# 0
# 1                       Show grace and understanding
# 2
# 3  Non-education related activities that increase...
# 4                         Tools to use in the moment
#
#                                  WellBeingSupport_18  \
# 0
# 1                         Listen to what people need
# 2
# 3  Ways of increasing normalcy, routine, and conn...
# 4                                              Space
#
#            CASELWebinars_16     CASELWebinars_17 CASELWebinars_18 Age  Race_1  \
# 0                                                                         NaN
# 1                                                                  39     NaN
# 2                                                                         NaN
# 3                                                                  36     NaN
# 4  Access to physical touch  Self reg strategies              EFT         NaN
#
#    Race_2  Race_3  Race_4  Race_5  Race_6  Race_7  Race_8 Race_8_TEXT  Gender  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN                 NaN
# 1     NaN     NaN     NaN     NaN     NaN     1.0     NaN                 2.0
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN                 NaN
# 3     NaN     NaN     NaN     NaN     NaN     1.0     NaN                 2.0
# 4     NaN     NaN     NaN     NaN     NaN     1.0     NaN                 2.0
#
#   Gender_3_TEXT  Educator  Role_11  Role_12  Role_1  Role_2  Role_3  Role_4  \
# 0                     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1                     2.0      NaN      NaN     NaN     NaN     NaN     NaN
# 2                     NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 3                     1.0      1.0      NaN     NaN     NaN     NaN     NaN
# 4                     1.0      NaN      NaN     NaN     NaN     NaN     NaN
#
#    Role_5  Role_6  Role_7  Role_8  Role_10 Role_10_TEXT  Grade_1  Grade_2  \
# 0     NaN     NaN     NaN     NaN      NaN                   NaN      NaN
# 1     NaN     NaN     NaN     NaN      NaN                   NaN      NaN
# 2     NaN     NaN     NaN     NaN      NaN                   NaN      NaN
# 3     NaN     NaN     NaN     NaN      NaN                   NaN      NaN
# 4     NaN     NaN     NaN     NaN      1.0  Private SLP      1.0      1.0
#
#    Grade_3  Grade_4  StudentSES_1
# 0      NaN      NaN           NaN
# 1      NaN      NaN           NaN
# 2      NaN      NaN           NaN
# 3      NaN      1.0           5.0
# 4      NaN      1.0           8.0

# %% [markdown]
# ### Look specifically at all the emotions people are feeling during the COVID-19 crisis

# %%
most_feelings_current_climate = []
aux = np.append(most_feelings_current_climate, df['OpenEmotions_1'])
aux2 = np.append(most_feelings_current_climate, df['OpenEmotions_3'])
aux3 = np.append(most_feelings_current_climate, df['OpenEmotions_4'])
all_strats = pd.Series(pd.Series([x.lower() for x in aux2]))
ordered_counts_strat = all_strats.value_counts()

# %% [markdown]
# #### Look at the initial most felt emotions

# %%
all_feelings_current_climate = all_strats
ordered_counts = all_feelings_current_climate.value_counts()
print("top ten feelings:\n", ordered_counts[0:10])
print('\n')
print("Number of Unique Feelings:", len(ordered_counts))
print('\n')
print("ten unique feelings:\n", ordered_counts[390:])
# Out:
# top ten feelings:
#  fear           308
# anxious        296
# anxiety        296
# overwhelmed    227
# sadness        170
# worry          160
# frustration    147
# stress         146
# uncertainty    144
# worried        133
# dtype: int64
#
#
# Number of Unique Feelings: 576
#
#
# ten unique feelings:
#  guilty          1
# uninformed      1
# surreal         1
# shame           1
# disturbed       1
#                ..
# ok              1
# responsible     1
# support         1
# separate        1
# hopefullness    1
# Length: 186, dtype: int64

# %% [markdown]
# ## Clean the data

# %%
# replace '-' with ' ', then remove punctuation
all_feelings_current_climate = [re.sub('-', ' ', all_feelings_current_climates) for all_feelings_current_climates in all_feelings_current_climate]
all_feelings_current_climate = [re.sub('[^\w\s]', '', all_feelings_current_climates) for all_feelings_current_climates in all_feelings_current_climate]

# replace multiple spaces by a single space
all_feelings_current_climate = [re.sub('[ ]+', ' ', all_feelings_current_climates) for all_feelings_current_climates in all_feelings_current_climate]

len(all_feelings_current_climate)
# Out:
# 5161

# %%
transcript_tokenized = []
for i in np.arange(len(all_feelings_current_climate)):
    processed = all_feelings_current_climate[i].lower().strip().split(', ')
    transcript_tokenized.append(processed)
emotion_clean = np.hstack(transcript_tokenized)
len(emotion_clean)
# Out:
# 5161

# %%
def is_numeric(string): ##Removes numerical responses
    for char in string:
        if char.isdigit():
            return True
    return False

def empty_string(string): ##Removes Empty Strings
    return string == ''

def remove_string(string):
    return is_numeric(string) | empty_string(string)

# %%
##removes empty spaces and numbers
temp = []
for token in emotion_clean:
    if not remove_string(token):
        temp.append(token)

emotion_token = temp
emotion_token
# Out:
# ['sad',
#  'fear',
#  'sadness',
#  'terror',
#  'concern',
#  'overwhelm',
#  'love',
#  'uncertainty',
#  'joy',
#  'isolated',
#  'isolated',
#  'fear',
#  'anxious',
#  'nervous',
#  'empathy',
#  'worried',
#  'anxious',
#  'anxiety',
#  'worry',
#  'insecurity',
#  'overwhelmed',
#  'fatigue',
#  'vulnerable',
#  'exhaustion',
#  'sadness',
#  'helpless',
#  'exasperated',
#  'fear',
#  'scared',
#  'boredom',
#  'grateful',
#  'anxious',
#  'drained',
#  'gratitude',
#  'helping',
#  'sadness',
#  'nervous tension',
#  'anxiety',
#  'sad',
#  'sad',
#  'sadness',
#  'anxious',
#  'frustration',
#  'anxiety',
#  'loving to others',
#  'concerned',
#  'stressed',
#  'fear',
#  'excitement',
#  'anger',
#  'gratitude',
#  'wonder',
#  'compassion',
#  'hopeful',
#  'vigilant',
#  'stress',
#  'irritated',
#  'sadness',
#  'overwhelmed',
#  'uncertain',
#  'uncertainty',
#  'worry',
#  'relaxed',
#  'anxiety',
#  'reflective',
#  'togetherness',
#  'stress',
#  'isolated',
#  'frustrated',
#  'unsure',
#  'anxious',
#  'frustrated',
#  'anxious',
#  'scared',
#  'scared',
#  'weariness',
#  'worried for students',
#  'uncertainty',
#  'worry',
#  'altered state',
#  'anxiety',
#  'motivation',
#  'anxious',
#  'doubt',
#  'anger',
#  'stressed',
#  'challenged',
#  'scared',
#  'anxious',
#  'challenged',
#  'uncertain',
#  'concerned',
#  'content',
#  'hope',
#  'protective',
#  'stressful',
#  'exhausted',
#  'anger',
#  'virtual relationships',
#  'nervous',
#  'uncertainty',
#  'isolated',
#  'loneliness',
#  'sadness',
#  'excited',
#  'optimism',
#  'frustration',
#  'empathy',
#  'gratitude',
#  'stress',
#  'impatience',
#  'sadness',
#  'anxious',
#  'sad',
#  'overwhelmed',
#  'confused',
#  'worry',
#  'anxiety',
#  'anxious',
#  'overwhelmed',
#  'stress',
#  'confusion',
#  'sad',
#  'stressed',
#  'anxiety',
#  'worried',
#  'sad',
#  'uncertainty',
#  'anxiety',
#  'overloaded',
#  'overwhelmed',
#  'unsure',
#  'frustration',
#  'frustrated',
#  'stress',
#  'anxiety',
#  'gratitude',
#  'anxious',
#  'determined',
#  'overwhelmed',
#  'volatile',
#  'overwhelmed',
#  'hopeful',
#  'hope',
#  'anxious',
#  'anxiety',
#  'worry',
#  'anxious',
#  'nervous',
#  'fear',
#  'fear',
#  'anxiety',
#  'uncertainty',
#  'anxiety',
#  'curious',
#  'sadness',
#  'concern',
#  'concerned',
#  'grateful',
#  'unmotivated',
#  'peace',
#  'curiosity',
#  'despair',
#  'worry',
#  'unprepared',
#  'loneliness',
#  'isolation',
#  'uncertain',
#  'loss',
#  'resolve',
#  'scared',
#  'overwhelmed',
#  'frustration',
#  'worry',
#  'exhaustion',
#  'lack of control',
#  'uncertain',
#  'hopeful',
#  'fear',
#  'nervous',
#  'lonely',
#  'worry',
#  'love',
#  'stress',
#  'confusion',
#  'concerned',
#  'overwhelmed',
#  'anxious',
#  'overwhelm',
#  'helpless',
#  'overwhelmed',
#  'purposeful',
#  'anxiety',
#  'fear',
#  'fear',
#  'stress',
#  'frustration',
#  'notconsentingtothissurvey',
#  'hopeful',
#  'unsure',
#  'confusion',
#  'overwhelm',
#  'hope',
#  'contentment',
#  'gratitude',
#  'unproductive',
#  'overwhelmed',
#  'anxious',
#  'confused',
#  'curious',
#  'sadness',
#  'overwhelmed',
#  'stress',
#  'gratitude',
#  'frustrated',
#  'empathy',
#  'motivated',
#  'anger',
#  'frustrated',
#  'exhausted',
#  'fear',
#  'uncertainty',
#  'fear',
#  'overwhelmed',
#  'alone',
#  'contentment',
#  'peaceful',
#  'frustration',
#  'fear',
#  'frustration',
#  'overwhelmed',
#  'unsettled',
#  'worry',
#  'stressed',
#  'frustration',
#  'calm',
#  'fear',
#  'anxious',
#  'isolated',
#  'anxious',
#  'concerned',
#  'sadness',
#  'fear',
#  'frustration',
#  'fear',
#  'helpless',
#  'fortitude',
#  'uncertain',
#  'satisfaction',
#  'sad',
#  'hope',
#  'uncertainity',
#  'exhaustion',
#  'stressed',
#  'worry',
#  'uncertainty',
#  'anxiety',
#  'anxious',
#  'concern',
#  'compassion',
#  'numb',
#  'annoyance',
#  'fear',
#  'heartfelt',
#  'dread',
#  'compassion',
#  'determination',
#  'peace',
#  'anxiety',
#  'angry',
#  'confused',
#  'fear',
#  'angry',
#  'fear',
#  'anxiety',
#  'exhaustion',
#  'empathy',
#  'unease',
#  'anxious',
#  'worried',
#  'anxious',
#  'stressed',
#  'sadness',
#  'fear',
#  'fear',
#  'anxiety',
#  'retrospective',
#  'stress',
#  'compassion',
#  'flexible',
#  'restless',
#  'patient',
#  'worried',
#  'anxious',
#  'stressed',
#  'anxious',
#  'worried',
#  'anxiety',
#  'frustration',
#  'inspired',
#  'gratitude',
#  'anxiety',
#  'fear',
#  'pressured',
#  'confusion',
#  'worry',
#  'fear',
#  'anxious',
#  'angry',
#  'concerned',
#  'sad',
#  'at ease',
#  'paranoias',
#  'confusion',
#  'worry',
#  'anxiety',
#  'sadness',
#  'confident',
#  'empathetic',
#  'uncertainty',
#  'connected',
#  'hope',
#  'urgency',
#  'uncertainty',
#  'stress',
#  'anxiety',
#  'anxious',
#  'exasperation',
#  'sadness',
#  'humbled',
#  'hope',
#  'stress',
#  'anxiousness',
#  'stressed',
#  'fear',
#  'lonely',
#  'stressed',
#  'confused',
#  'worry',
#  'powerless',
#  'uncertainty',
#  'stressed',
#  'uncertain',
#  'fearful',
#  'mindful',
#  'frustrated',
#  'frustration',
#  'confusion',
#  'optimist',
#  'anxiety',
#  'insecurities',
#  'unsettled',
#  'relaxed',
#  'joy',
#  'hopeful',
#  'angry',
#  'concern',
#  'frustration',
#  'secluded',
#  'ineffectiveness',
#  'not respected',
#  'grief',
#  'uncertain',
#  'tired',
#  'worry',
#  'overwhelmed',
#  'uncertainty',
#  'exhaustion',
#  'sad',
#  'sad',
#  'amazement',
#  'confused',
#  'anxiety',
#  'confused',
#  'abundance',
#  'stress',
#  'stress',
#  'stress',
#  'resolute',
#  'worry',
#  'distructive',
#  'restlessness',
#  'uncertainty',
#  'confusion',
#  'hopeful',
#  'loneliness',
#  'unimportant',
#  'frustrated',
#  'compassion',
#  'frustration',
#  'uncertain',
#  'fear',
#  'mistrust',
#  'rushed',
#  'calm',
#  'overwhelmed',
#  'uncertainty',
#  'anger',
#  'grateful',
#  'uncertain',
#  'overwhelmed',
#  'fearful',
#  'worry',
#  'fear',
#  'worried',
#  'fear',
#  'frustration',
#  'overwhelmed',
#  'relieved',
#  'uncertainty',
#  'anxiety',
#  'anxiety',
#  'anger',
#  'fear',
#  'anger',
#  'uncertain',
#  'anxious',
#  'empathy',
#  'curiousness',
#  'overwhelmed',
#  'anxiety',
#  'accepting',
#  'supported',
#  'gratitude',
#  'fear',
#  'strength',
#  'anxiety',
#  'anxious',
#  'worry',
#  'fearful',
#  'nervous',
#  'anxiety',
#  'y',
#  'anxious',
#  'hopeful',
#  'lethargic',
#  'bummed',
#  'sadness',
#  'gratitude',
#  'nervousness',
#  'overwhelmed',
#  'lonely',
#  'sadness',
#  'gratefulness',
#  'stress',
#  'anxious',
#  'solidarity',
#  'concern',
#  'fear',
#  'worried',
#  'hopeful',
#  'growth',
#  'angry',
#  'frustrated',
#  'hope',
#  'worry',
#  'motivated',
#  'lonley',
#  'protective',
#  'anxious',
#  'diversity',
#  'concern',
#  'overwhelmed',
#  'irritation',
#  'overwhelmed',
#  'uneasy',
#  'responsible',
#  'worried',
#  'sadness',
#  'gratitude',
#  'calm',
#  'empathetic',
#  'hopelessness',
#  'fear',
#  'worried',
#  'hope',
#  'sadness',
#  'ambitious',
#  'sadness',
#  'fear',
#  'sad',
#  'questioning',
#  'uncertainty',
#  'distracted',
#  'loneliness',
#  'confusion',
#  'unsure',
#  'calm',
#  'pressure',
#  'anxious',
#  'anxious',
#  'loss of control',
#  'overwhelmed',
#  'uncertainty',
#  'strange',
#  'rhythm',
#  'frustration',
#  'frustration',
#  'sad',
#  'anxious',
#  'drained',
#  'lonliness',
#  'anxiety',
#  'anxious',
#  'fear',
#  'fear',
#  'anxious',
#  'heartbreak',
#  'calm',
#  'fear',
#  'stressed',
#  'anxious',
#  'gratitude',
#  'disconnect',
#  'sadness',
#  'grief',
#  'uncertain',
#  'uncertainty',
#  'anxious',
#  'stress',
#  'uncertainty',
#  'stress',
#  'anxious',
#  'sadness',
#  'frustration',
#  'worried',
#  'anxious',
#  'concern',
#  'fear',
#  'challenging difficult',
#  'overwhelmed',
#  'blessed',
#  'scared',
#  'fear',
#  'stressed',
#  'motivated',
#  'determination',
#  'unbalanced',
#  'anxious',
#  'hopeful',
#  'angry',
#  'fear',
#  'stress',
#  'tired',
#  'critical',
#  'sadness',
#  'anxiety',
#  'frustrated',
#  'anxiety',
#  'stressed',
#  'anxious',
#  'sad',
#  'fear',
#  'panicked',
#  'overwhelmed',
#  'hopeful',
#  'fear',
#  'stress',
#  'flat',
#  'anxious',
#  'expectant',
#  'worried',
#  'freedom',
#  'disappointed',
#  'fear',
#  'sad',
#  'frustration',
#  'disappointed',
#  'bored',
#  'helpful',
#  'unprepared',
#  'sad',
#  'persistent',
#  'anxiety',
#  'scared',
#  'uncertain',
#  'anxiety',
#  'exhausted',
#  'worry',
#  'overwhelmed',
#  'concerned',
#  'guilt',
#  'hope',
#  'grateful',
#  'unprepared',
#  'fear',
#  'stressed',
#  'worry',
#  'helpless',
#  'helpless',
#  'worried',
#  'supported',
#  'fear',
#  'stressed',
#  'loneliness',
#  'isolation',
#  'uncertainty',
#  'fear',
#  'stressed',
#  'worry',
#  'overwhelmed',
#  'unsure',
#  'urgency',
#  'wary',
#  'helplessness',
#  'enthusiastic',
#  'disconnected',
#  'uncertain',
#  'scared',
#  'fear',
#  'hope',
#  'sadness',
#  'optimism',
#  'anxious',
#  'anxiousness',
#  'uncertain',
#  'powerless',
#  'frustration',
#  'concerned',
#  'anxious',
#  'stressed',
#  'affection',
#  'boredom',
#  'gratitude',
#  'concern',
#  'grateful',
#  'grief',
#  'surreal feeling',
#  'anxiety',
#  'concern',
#  'bored',
#  'reassured',
#  'sadness',
#  'innovative',
#  'angry',
#  'challenged',
#  'anxious',
#  'exhaustion',
#  'grateful',
#  'helpless',
#  'joy',
#  'relief',
#  'hopelessness',
#  'unsure',
#  'anxiety',
#  'hope',
#  'sad',
#  'fret',
#  'stress',
#  'fear',
#  'anger',
#  'exhaustion',
#  'worried',
#  'worry',
#  'exhausted',
#  'worry',
#  'sadness',
#  'overwhelmed',
#  'empathy',
#  'depression',
#  'fear',
#  'frustration',
#  'stress',
#  'concerned',
#  'anxious',
#  'connection',
#  'anxious',
#  'bordom',
#  'frustration',
#  'worry',
#  'sad',
#  'stress',
#  'community',
#  'concerned',
#  'sad',
#  'hopelessness',
#  'fear',
#  'overwhelmed',
#  'uncontrollable',
#  'unsafe',
#  'charity',
#  'protectiveness',
#  'helplessness',
#  'worried',
#  'fear',
#  'helpless',
#  'concerned',
#  'contained',
#  'sadness',
#  'stress',
#  'worry',
#  'fear',
#  'sadness',
#  'alert',
#  'excited',
#  'sadness',
#  'overwhelmed',
#  'overwhelmed',
#  'fear',
#  'overwhelmed',
#  'hope',
#  'frustration',
#  'fear',
#  'worried',
#  'concerned',
#  'fear',
#  'anxiety',
#  'grateful',
#  'fear',
#  'isolation',
#  'worry',
#  'gratitude',
#  'worry',
#  'peace',
#  'sad',
#  'sadness',
#  'exhausted',
#  'nervous',
#  'worry',
#  'stress',
#  'frustration',
#  'curious',
#  'stressed',
#  'joy',
#  'loneliness',
#  'sadness',
#  'fearful',
#  'overwhelmed',
#  'fear',
#  'sadness',
#  'fear',
#  'curious',
#  'concern',
#  'seclusion',
#  'sad',
#  'loneliness',
#  'stressed',
#  'fear',
#  'stressed',
#  'confused',
#  'lonliness',
#  'relaxed',
#  'anxious',
#  'confusion',
#  'anxious',
#  'curiosity',
#  'focused',
#  'frustration',
#  'buzzing',
#  'tired',
#  'gratefulness',
#  'exhilarated',
#  'stuck',
#  'gratitude',
#  'uncertainty',
#  'fear',
#  'scarey',
#  'unsettled',
#  'overwhelmed',
#  'subdued',
#  'anxiety',
#  'calm',
#  'isolated',
#  'pressure',
#  'tired',
#  'disappointed',
#  'sadness',
#  'alienation',
#  'worried',
#  'scared',
#  'aloof',
#  'solemn',
#  'hopeful',
#  'grateful',
#  'anxiety',
#  'frustration',
#  'stressed',
#  'fear',
#  'calm',
#  'hope',
#  'concerned',
#  'sadness',
#  'worry',
#  'anxiety',
#  'fear',
#  'worried',
#  'grief',
#  'uncertainty',
#  'stressed',
#  'sad',
#  'overwhelmed',
#  'worry',
#  'scared',
#  'nervous',
#  'anxiety',
#  'strong',
#  'calm',
#  'frustration',
#  'protective',
#  'irritable',
#  'worried',
#  'nervous',
#  'anxious',
#  'anger',
#  'fear',
#  'uncertainty',
#  'fear',
#  'fear',
#  'tired',
#  'worried',
#  'anxious',
#  'worry',
#  'useless',
#  'thankful',
#  'curiosity',
#  'frustration',
#  'concern',
#  'uneasy',
#  'uncertainty',
#  'tired',
#  'anxious',
#  'fear',
#  'thankfulness',
#  'anxiety',
#  'scattered',
#  'confused',
#  'anxious',
#  'uncertain',
#  'sad',
#  'happy',
#  'uncertainty',
#  'relaxed',
#  'caution',
#  'confused',
#  'fear',
#  'fear',
#  'stressed',
#  'thankful',
#  'fear',
#  'fear',
#  'melancholy',
#  'overwhelmed',
#  'fearful',
#  'concern',
#  'grateful',
#  'energized',
#  'stress',
#  'stress',
#  'anxiety',
#  'uncertainty',
#  'fear',
#  'defeated',
#  'confused',
#  'frustrated',
#  'fear',
#  'frustrated',
#  'overwhelmed',
#  'feeling lost',
#  'bored',
#  'panic',
#  'hope',
#  'stressed',
#  'anxious',
#  'tired',
#  'nervous',
#  'anxiety',
#  'excited',
#  'helplessness',
#  'hopeful',
#  'anger',
#  'disappointment',
#  'anxiety',
#  'panic',
#  'confusion',
#  'stress',
#  'anxiety',
#  'overwhelmed',
#  'disconnected',
#  'sad',
#  'empathy',
#  'scared',
#  'anxiety',
#  'overwhelmed',
#  'eager',
#  'creative',
#  'frustation',
#  'fear',
#  'fear',
#  'anxiety',
#  'anxiety',
#  'confusion',
#  'stress',
#  'lonely',
#  'uncertainty',
#  'doubt',
#  'unmoored',
#  'calm',
#  'ready',
#  'sadness',
#  'anxious',
#  'worried',
#  'usure',
#  'stressed',
#  'worry',
#  'overwhelmed',
#  'anxious',
#  'anxiety',
#  'curiosity',
#  'boredom',
#  'uncertainty',
#  'stressed',
#  'stress',
#  'confused',
#  'sadness',
#  'happy',
#  'disappointed',
#  'anxious',
#  'uncertainty',
#  'confusion',
#  'anxiety',
#  'grateful',
#  'anxious',
#  'frustration',
#  'unrest',
#  'anxiety',
#  'frustration',
#  'worried',
#  'alone',
#  'guilt',
#  'frustration',
#  'fearful',
#  'disappointment',
#  'unknowing',
#  'focused',
#  'isolated',
#  'overwhelemed',
#  'exhausted',
#  'scared',
#  'anxious',
#  'sad',
#  'worry',
#  'tired',
#  'helpless',
#  'uncertainty',
#  'anxiety',
#  'overload',
#  'disoriented',
#  'anger',
#  'overhelmed',
#  'gratitude',
#  'overwhelmed',
#  'uncertain',
#  'lonely',
#  'overwhelm',
#  'anxiety',
#  'uncertainty',
#  'anxious',
#  'happy',
#  'frustration',
#  'uncertainty',
#  'compassion',
#  'fear',
#  'scared',
#  'confusion',
#  'depressed',
#  'anxious',
#  'uncertainty',
#  'fear',
#  'panic',
#  'confused',
#  'anticiaption',
#  'frustrated',
#  'amor',
#  'helpless',
#  'stressed',
#  'eustressed',
#  'scared',
#  'exhausted',
#  'fear',
#  'anxious',
#  'worry',
#  'stressed',
#  'overwhelm',
#  'unmotivated',
#  'excited',
#  'motivated',
#  'sadness',
#  'anxiety',
#  'worried',
#  'uncertain',
#  'frustrated',
#  'anxiety',
#  'bored',
#  'disappointment',
#  'worried',
#  'sadness',
#  'resignation',
#  'gratitude',
#  'pain',
#  'anxious',
#  ...]

# %%
def single_and_multi(emotion_token):
    long_resp =[]
    short_resp = []
    for i in emotion_token:
            if len(i.split()) > 1:
                long_resp = np.append(long_resp, i)  
            else:
                short_resp = np.append(short_resp, i)
                
    #Returns a list of to lists short and long responses
    return [short_resp, long_resp]

# %%
len(single_and_multi(emotion_token)[0])
# Out:
# 4938

# %%
single = single_and_multi(emotion_token)
def misspelled(single_words):
    spell = SpellChecker()

    misspelled = spell.unknown(single_words)
    correct = spell.known(single_words)
    list_misspelled = list(misspelled)
    return list_misspelled


wrong_words = list(misspelled(single[0]))

def corrections(misspelled):
    correction_list = []
    for word in misspelled:
        # Get the one `most likely` answer
        correction = spell.correction(word)
        correction_list = np.append(correction_list, correction)
    #returns two lists, one of the wrong words, one the correct
    return [misspelled, correction_list]

corrections(wrong_words)
correct_single_words = spell.known(single[0])
corrected_single_words = corrections(wrong_words)[1]
long_responses = single[1]

type(long_responses)
#new_word_list = correct_single_words + corrected_single_words + long_responses
# Out:
# numpy.ndarray

# %%
# correction = corrections(wrong_words)

# d = {'misspelled' : corrections[0],
#      'correction_list': corrections[1]}
# pd.DataFrame(d)
corrections(wrong_words)
# Out:
# [['ovewhelmed',
#   'hopefullness',
#   'selfconfidence',
#   'compasion',
#   'nervouse',
#   'unmmotivated',
#   'wowed',
#   'reiliance',
#   'disagrement',
#   'disappointmemt',
#   'jou',
#   'curiousity',
#   'discombobulated',
#   'coraje',
#   'sadnesz',
#   'intruiged',
#   'mindfulness',
#   'greif',
#   'aprehension',
#   'oberwhelmed',
#   'acceptence',
#   'vigor',
#   'saddness',
#   'helplessnes',
#   'frustation',
#   'overstimulated',
#   'scatterdness',
#   'underappreciated',
#   'preocuppied',
#   'gratitud',
#   'emotionalteary',
#   'gloominess',
#   'stressuncertainty',
#   'notconsentingtothissurvey',
#   'gradititude',
#   'overwhlemed',
#   'disappoinment',
#   'sureal',
#   'pensiveness',
#   'lonliness',
#   'cinfused',
#   'optimisim',
#   'wortied',
#   'overthinking',
#   'unuseful',
#   'uncertaint',
#   'fired_up',
#   'overwhelemed',
#   'uncentered',
#   'lonley',
#   'gratefulness',
#   'helplesss',
#   'disconnectedness',
#   'micromanaged',
#   'stressfull',
#   'disapppointment',
#   'meh',
#   'releived',
#   'bummed',
#   'uncertainity',
#   'sleepliness',
#   'fruatated',
#   'overwhelmned',
#   'dispair',
#   'unmoored',
#   'unaccomplished',
#   'miedo',
#   'anxietydread',
#   'nonproductive',
#   'suppory',
#   'prayful',
#   'disregulated',
#   'unknowingness',
#   'antsy',
#   'lonlieness',
#   'fewr',
#   'greatful',
#   'happyrelief',
#   'figuroutable',
#   'anxiousness',
#   'introsepective',
#   'uninspiried',
#   'serviceful'],
#  array(['overwhelmed', 'hopefulness', 'self-confidence', 'companion',
#         'nervous', 'unmotivated', 'owed', 'reliance', 'disagreement',
#         'disappointment', 'you', 'curiosity', 'discombobulated', 'core',
#         'sadness', 'intrigued', 'sinfulness', 'grief', 'apprehension',
#         'overwhelmed', 'acceptance', 'vigour', 'sadness', 'helplessness',
#         'frustration', 'overstimulated', 'scatterdness',
#         'underappreciated', 'preoccupied', 'gratitude', 'emotionalteary',
#         'gloomiest', 'stressuncertainty', 'notconsentingtothissurvey',
#         'gratitude', 'overwhelmed', 'disappointment', 'surreal',
#         'pensiveness', 'loneliness', 'confused', 'optimism', 'worried',
#         'overthinking', 'useful', 'uncertainty', 'fired-up', 'overwhelmed',
#         'unfettered', 'lonely', 'gracefulness', 'helpless',
#         'disconnectedness', 'micromanaged', 'stressful', 'disappointment',
#         'me', 'received', 'summed', 'uncertainty', 'sleepiness',
#         'frustrated', 'overwhelmed', 'despair', 'moored', 'accomplished',
#         'mind', 'anxietydread', 'non-productive', 'support', 'playful',
#         'deregulated', 'knowingness', 'ants', 'loneliness', 'few',
#         'grateful', 'happyrelief', 'figuroutable', 'anxiousness',
#         'introspective', 'uninspired', 'serviceful'], dtype='<U32')]

# %%
d = pd.Series(emotion_token).value_counts()

df = pd.DataFrame(d)
df.to_excel("Open Emotion First Response Data Second.xlsx", sheet_name='second response')

# %%
new_word_list = np.concatenate((list(correct_single_words), corrected_single_words, long_responses), axis = None)


len(new_word_list)
# Out:
# 691

# %% [markdown]
# ## Creates a list of all properly spelled words

# %%
def properlyspelled(cleaned_emotion_tokens):
    long_resp = []
    short_resp = []
    for i in cleaned_emotion_tokens:
        if len(i.split()) > 1:
            long_resp = np.append(long_resp, i)  
        else:
            short_resp = np.append(short_resp, i)
    spell = SpellChecker()
    misspelled = spell.unknown(short_resp)
    list_misspelled = list(misspelled)

    list_misspelled = np.append(list_misspelled, 'disorientate')
    list_misspelled = np.append(list_misspelled, 'vunerable')

    #Remove misspelled words
    list1 = [ele for ele in short_resp if ele not in list_misspelled]
    return list1

# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
   
ps = PorterStemmer() 
  
# choose some words to be stemmed 
words = properlyspelled(emotion_token)

new_words = []
for w in words:
    new_words = np.append(new_words, ps.stem(w))
    
test = pd.Series(new_words)
    
open_emotion = pd.Series(properlyspelled(emotion_token))

ordered_counts_test = test.value_counts()
ordered_counts = open_emotion.value_counts()
#print("top ten feelings:\n", ordered_counts_test[30:90])
len(words)
# Out:
# 14651

# %%
##Compresses Repeated Values, so every value is unique
unique_emotion_tokens = list(set(emotion_token))
print("There are", len(unique_emotion_tokens),"unique emotion words in the emotion data")
# Out:
# There are 1070 unique emotion words in the emotion data

# %% [markdown]
# ## So far, we have cleaned our data down to 1070 unique tokens form an original 15,000+ responses.
#
# **Next Steps**
# - Split the tokens into single word and multiword responses
# - Look at the misspelled words in the data
# - Lemmetize the data and compress to unique values again
# -
# -
# -
# -
#
# **There are misspelling in the data. Let deal with that by looking at the misspelled words**

# %% [markdown]
# ### Step 1: Splits the tokens into single word and multiword responses
# Calls single word responses short_resp and multiword responses long_resp

# %%
long_resp = []
short_resp = []
for i in unique_emotion_tokens:
    if len(i.split()) > 1:
        long_resp = np.append(long_resp, i)  
    else:
        short_resp = np.append(short_resp, i)
len(long_resp)
# Out:
# 138

# %% [markdown]
# ### Step 2: Looks at the misspelled words in the data
# Removes misspelled words from the data
#
# # FLAG
# Should the misspelled data be completely removed?

# %%
spell = SpellChecker()
misspelled = spell.unknown(short_resp)
list_misspelled = list(misspelled)

list_misspelled = np.append(list_misspelled, 'disorientate')
list_misspelled = np.append(list_misspelled, 'vunerable')

#Remove misspelled words
list1 = [ele for ele in short_resp if ele not in list_misspelled]
len(list1)
# Out:
# 767
